# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import preprocessing

# %%
data = pd.read_csv("../XRPUSDT_Dataset/XRP_dataset.csv")

# %%
open_price = np.array(data["open"].to_list())

# %% [markdown]
# ### Normalization

# %%
normalized_arr = preprocessing.normalize([open_price])

# %%
plt.plot(list(normalized_arr[0]))
